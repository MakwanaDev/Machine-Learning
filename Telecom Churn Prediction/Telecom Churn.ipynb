# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Data Exploration and Pre-processing

# %% [markdown]
# ### 1) load the given dataset

# %%
df = pd.read_csv('Telecom Churn Data.csv')

# %%
df.shape
# Out:
# (2666, 20)

# %%
pd.set_option('display.max_columns',None)

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 2661    SC              79        415                 No              No
# 2662    AZ             192        415                 No             Yes
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# ...                     ...                ...              ...
# 2661                      0              134.7               98
# 2662                     36              156.2               77
# 2663                      0              231.1               57
# 2664                      0              180.8              109
# 2665                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0                45.07              197.4               99             16.78
# 1                27.47              195.5              103             16.62
# 2                41.38              121.2              110             10.30
# 3                50.90               61.9               88              5.26
# 4                28.34              148.3              122             12.61
# ...                ...                ...              ...               ...
# 2661             22.90              189.7               68             16.12
# 2662             26.55              215.5              126             18.32
# 2663             39.29              153.4               55             13.04
# 2664             30.74              288.8               58             24.55
# 2665             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 2661                221.4                128                9.96
# 2662                279.1                 83               12.56
# 2663                191.3                123                8.61
# 2664                191.9                 91                8.64
# 2665                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 2661                11.8                 5               3.19
# 2662                 9.9                 6               2.67
# 2663                 9.6                 4               2.59
# 2664                14.1                 6               3.81
# 2665                13.7                 4               3.70
#
#       Customer service calls  Churn
# 0                          1  False
# 1                          1  False
# 2                          0  False
# 3                          2  False
# 4                          3  False
# ...                      ...    ...
# 2661                       2  False
# 2662                       2  False
# 2663                       3  False
# 2664                       2  False
# 2665                       0  False
#
# [2666 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666 entries, 0 to 2665
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   2666 non-null   object
#  1   Account length          2666 non-null   int64
#  2   Area code               2666 non-null   int64
#  3   International plan      2666 non-null   object
#  4   Voice mail plan         2666 non-null   object
#  5   Number vmail messages   2666 non-null   int64
#  6   Total day minutes       2666 non-null   float64
#  7   Total day calls         2666 non-null   int64
#  8   Total day charge        2666 non-null   float64
#  9   Total eve minutes       2666 non-null   float64
#  10  Total eve calls         2666 non-null   int64
#  11  Total eve charge        2666 non-null   float64
#  12  Total night minutes     2666 non-null   float64
#  13  Total night calls       2666 non-null   int64
#  14  Total night charge      2666 non-null   float64
#  15  Total intl minutes      2666 non-null   float64
#  16  Total intl calls        2666 non-null   int64
#  17  Total intl charge       2666 non-null   float64
#  18  Customer service calls  2666 non-null   int64
#  19  Churn                   2666 non-null   bool
# dtypes: bool(1), float64(8), int64(8), object(3)
# memory usage: 398.5+ KB

# %% [markdown]
# ### 2) print all the column names

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df['State'].unique()
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'WV', 'RI', 'IA', 'MT',
#        'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'NE', 'WY', 'IL', 'NH',
#        'LA', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR', 'DE', 'IN', 'UT', 'CA',
#        'SD', 'NC', 'WA', 'MN', 'NM', 'NV', 'DC', 'NY', 'KY', 'ME', 'MS',
#        'MI', 'SC', 'TN', 'PA', 'HI', 'ND', 'CT'], dtype=object)

# %% [markdown]
# ### 3) describe the data

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     2666.000000  2666.000000            2666.000000         2666.00000
# mean       100.620405   437.438860               8.021755          179.48162
# std         39.563974    42.521018              13.612277           54.21035
# min          1.000000   408.000000               0.000000            0.00000
# 25%         73.000000   408.000000               0.000000          143.40000
# 50%        100.000000   415.000000               0.000000          179.95000
# 75%        127.000000   510.000000              19.000000          215.90000
# max        243.000000   510.000000              50.000000          350.80000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      2666.000000       2666.000000        2666.000000      2666.000000
# mean        100.310203         30.512404         200.386159       100.023631
# std          19.988162          9.215733          50.951515        20.161445
# min           0.000000          0.000000           0.000000         0.000000
# 25%          87.000000         24.380000         165.300000        87.000000
# 50%         101.000000         30.590000         200.900000       100.000000
# 75%         114.000000         36.700000         235.100000       114.000000
# max         160.000000         59.640000         363.700000       170.000000
#
#        Total eve charge  Total night minutes  Total night calls  \
# count       2666.000000          2666.000000        2666.000000
# mean          17.033072           201.168942         100.106152
# std            4.330864            50.780323          19.418459
# min            0.000000            43.700000          33.000000
# 25%           14.050000           166.925000          87.000000
# 50%           17.080000           201.150000         100.000000
# 75%           19.980000           236.475000         113.000000
# max           30.910000           395.000000         166.000000
#
#        Total night charge  Total intl minutes  Total intl calls  \
# count         2666.000000         2666.000000       2666.000000
# mean             9.052689           10.237022          4.467367
# std              2.285120            2.788349          2.456195
# min              1.970000            0.000000          0.000000
# 25%              7.512500            8.500000          3.000000
# 50%              9.050000           10.200000          4.000000
# 75%             10.640000           12.100000          6.000000
# max             17.770000           20.000000         20.000000
#
#        Total intl charge  Customer service calls
# count        2666.000000             2666.000000
# mean            2.764490                1.562641
# std             0.752812                1.311236
# min             0.000000                0.000000
# 25%             2.300000                1.000000
# 50%             2.750000                1.000000
# 75%             3.270000                2.000000
# max             5.400000                9.000000

# %% [markdown]
# ### 4) find all the Null values

# %%
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %% [markdown]
# ### 5) plot the customers who have international plans

# %%
sns.countplot(x = 'International plan',data=df)
print(df['International plan'].value_counts())
# Out:
# No     2396
# Yes     270
# Name: International plan, dtype: int64

# %% [markdown]
# ### 6) plot the customers who have Voice mail plan

# %%
sns.countplot(x = 'Voice mail plan',data=df)
print(df['Voice mail plan'].value_counts())
# Out:
# No     1933
# Yes     733
# Name: Voice mail plan, dtype: int64

# %% [markdown]
# ### 7) Plot the total day calls

# %%
sns.set(rc={'figure.figsize':(12,6)})
sns.distplot(df['Total day calls'])
# Out:
# C:\Users\dmaka\AppData\Local\Temp\ipykernel_12840\1631205346.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Total day calls'])
# <Axes: xlabel='Total day calls', ylabel='Density'>

# %% [markdown]
# ### 8) Plot the total day charge

# %%
sns.set(rc={'figure.figsize':(12,6)})
sns.distplot(df['Total day charge'], color='red')
# Out:
# C:\Users\dmaka\AppData\Local\Temp\ipykernel_12840\49279185.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Total day charge'], color='red')
# <Axes: xlabel='Total day charge', ylabel='Density'>

# %% [markdown]
# ### 9) Display pie chart for value count in Churn column

# %%
df['Churn'].value_counts()
df['Churn'].unique()
# Out:
# array([False,  True])

# %%
values = [len(df['Churn'][df['Churn']==False]),len(df['Churn'][df['Churn']==True])]
plt.pie(values,labels=df['Churn'].unique())
# Out:
# ([<matplotlib.patches.Wedge at 0x23d30f2e890>,
#   <matplotlib.patches.Wedge at 0x23d30f2e7a0>],
#  [Text(-0.987013487405142, 0.4855969271734941, 'False'),
#   Text(0.9870135101375737, -0.4855968809680577, 'True')])

# %% [markdown]
# ### 10) Display a scatter plot between total day calls and total day charges

# %%
plt.xlabel('Total Day Calls')
plt.ylabel('Total Day Charge')
plt.scatter(df['Total day calls'],df['Total day charge'])

# %%
sns.set(rc={'figure.figsize':(12,8)})
sns.scatterplot(data=df,x="Total day calls",y="Total day charge",hue="Churn")
# Out:
# <Axes: xlabel='Total day calls', ylabel='Total day charge'>

# %% [markdown]
# ### 11) Display a scatter plot between total day calls and total night calls

# %%
plt.xlabel('Total Day Calls')
plt.ylabel('Total Night Calls')
plt.scatter(df['Total day calls'],df['Total night calls'],c='green')

# %%
sns.scatterplot(data=df,x="Total day calls",y="Total night charge",hue="Churn")
# Out:
# <Axes: xlabel='Total day calls', ylabel='Total night charge'>

# %%
#sns.set(rc={'figure.figsize':(12,8)})
#sns.relplot(x='Total day calls',y='Total night calls',hue='Churn',data=df)

# %% [markdown]
# ### 12) Display a boxplot of Total day minutes with respect to Churn

# %%
sns.set(rc={'figure.figsize':(8,6)})
sns.boxplot(x = 'Churn',y = 'Total day minutes',data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='Total day minutes'>

# %% [markdown]
# ### 13) Display a boxplot of Total day charge with respect to Churn

# %%
sns.set(rc={'figure.figsize':(8,6)})
sns.boxplot(x = 'Churn',y = 'Total day charge',data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='Total day charge'>

# %% [markdown]
# # Working with models

# %% [markdown]
# ### 1) Perform encoding on churn

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df1 = df.copy()

# %%
df1['Churn'] = df['Churn'] = LabelEncoder().fit_transform(df1['Churn'])

# %%
df1['Churn']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2661    0
# 2662    0
# 2663    0
# 2664    0
# 2665    0
# Name: Churn, Length: 2666, dtype: int64

# %% [markdown]
# ### 2) Perform encoding on International Plan

# %%
df1['International plan'] = LabelEncoder().fit_transform(df1['International plan'])

# %%
df1['International plan']
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 2661    0
# 2662    0
# 2663    0
# 2664    0
# 2665    0
# Name: International plan, Length: 2666, dtype: int32

# %% [markdown]
# ### 3) Perform encoding on voice mail plan using sklearn

# %%
df1['Voice mail plan'] = LabelEncoder().fit_transform(df1['Voice mail plan'])

# %%
df1['Voice mail plan']
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 2661    0
# 2662    1
# 2663    0
# 2664    0
# 2665    1
# Name: Voice mail plan, Length: 2666, dtype: int32

# %% [markdown]
# ### 4) Check the correlation among all the columns

# %%
df1.corr()
# Out:
# C:\Users\dmaka\AppData\Local\Temp\ipykernel_12840\473017434.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#                         Account length  Area code  International plan  \
# Account length                1.000000  -0.008620            0.024500
# Area code                    -0.008620   1.000000            0.047099
# International plan            0.024500   0.047099            1.000000
# Voice mail plan               0.002448   0.007180            0.002131
# Number vmail messages        -0.002996  -0.000584            0.005858
# Total day minutes             0.002847  -0.023134            0.049550
# Total day calls               0.038862  -0.009629           -0.004277
# Total day charge              0.002843  -0.023130            0.049555
# Total eve minutes            -0.015923   0.000679            0.026616
# Total eve calls               0.018552  -0.018602            0.010277
# Total eve charge             -0.015909   0.000707            0.026623
# Total night minutes          -0.008994  -0.003353           -0.010310
# Total night calls            -0.024007   0.011455            0.018081
# Total night charge           -0.008999  -0.003382           -0.010316
# Total intl minutes            0.011369  -0.013418            0.053162
# Total intl calls              0.017627  -0.027423            0.011549
# Total intl charge             0.011383  -0.013534            0.053037
# Customer service calls        0.002455   0.034442           -0.035955
# Churn                         0.017728   0.001019            0.277489
#
#                         Voice mail plan  Number vmail messages  \
# Account length                 0.002448              -0.002996
# Area code                      0.007180              -0.000584
# International plan             0.002131               0.005858
# Voice mail plan                1.000000               0.957159
# Number vmail messages          0.957159               1.000000
# Total day minutes              0.013438               0.019027
# Total day calls               -0.007541              -0.009622
# Total day charge               0.013439               0.019027
# Total eve minutes              0.019132               0.011401
# Total eve calls                0.003404               0.005131
# Total eve charge               0.019147               0.011418
# Total night minutes            0.001065              -0.000224
# Total night calls              0.013985               0.008124
# Total night charge             0.001066              -0.000229
# Total intl minutes            -0.013963              -0.004156
# Total intl calls               0.015196               0.027013
# Total intl charge             -0.013931              -0.004136
# Customer service calls        -0.022054              -0.018787
# Churn                         -0.099291              -0.086474
#
#                         Total day minutes  Total day calls  Total day charge  \
# Account length                   0.002847         0.038862          0.002843
# Area code                       -0.023134        -0.009629         -0.023130
# International plan               0.049550        -0.004277          0.049555
# Voice mail plan                  0.013438        -0.007541          0.013439
# Number vmail messages            0.019027        -0.009622          0.019027
# Total day minutes                1.000000         0.016780          1.000000
# Total day calls                  0.016780         1.000000          0.016787
# Total day charge                 1.000000         0.016787          1.000000
# Total eve minutes                0.003999        -0.026003          0.004008
# Total eve calls                  0.009059         0.006473          0.009056
# Total eve charge                 0.003992        -0.026006          0.004002
# Total night minutes              0.013491         0.008986          0.013495
# Total night calls                0.015054        -0.016776          0.015057
# Total night charge               0.013464         0.008972          0.013468
# Total intl minutes              -0.011042         0.031036         -0.011046
# Total intl calls                 0.005687         0.006928          0.005688
# Total intl charge               -0.010934         0.031133         -0.010938
# Customer service calls          -0.024543        -0.011945         -0.024548
# Churn                            0.195688         0.018290          0.195689
#
#                         Total eve minutes  Total eve calls  Total eve charge  \
# Account length                  -0.015923         0.018552         -0.015909
# Area code                        0.000679        -0.018602          0.000707
# International plan               0.026616         0.010277          0.026623
# Voice mail plan                  0.019132         0.003404          0.019147
# Number vmail messages            0.011401         0.005131          0.011418
# Total day minutes                0.003999         0.009059          0.003992
# Total day calls                 -0.026003         0.006473         -0.026006
# Total day charge                 0.004008         0.009056          0.004002
# Total eve minutes                1.000000        -0.007654          1.000000
# Total eve calls                 -0.007654         1.000000         -0.007642
# Total eve charge                 1.000000        -0.007642          1.000000
# Total night minutes             -0.013414        -0.000175         -0.013428
# Total night calls                0.009017         0.000797          0.009030
# Total night charge              -0.013450        -0.000135         -0.013464
# Total intl minutes              -0.006915         0.011012         -0.006923
# Total intl calls                 0.002160         0.003710          0.002169
# Total intl charge               -0.006947         0.011000         -0.006955
# Customer service calls          -0.013192         0.001058         -0.013196
# Churn                            0.072906        -0.001539          0.072893
#
#                         Total night minutes  Total night calls  \
# Account length                    -0.008994          -0.024007
# Area code                         -0.003353           0.011455
# International plan                -0.010310           0.018081
# Voice mail plan                    0.001065           0.013985
# Number vmail messages             -0.000224           0.008124
# Total day minutes                  0.013491           0.015054
# Total day calls                    0.008986          -0.016776
# Total day charge                   0.013495           0.015057
# Total eve minutes                 -0.013414           0.009017
# Total eve calls                   -0.000175           0.000797
# Total eve charge                  -0.013428           0.009030
# Total night minutes                1.000000           0.012736
# Total night calls                  0.012736           1.000000
# Total night charge                 0.999999           0.012720
# Total intl minutes                -0.008607          -0.023447
# Total intl calls                  -0.001110           0.019367
# Total intl charge                 -0.008510          -0.023434
# Customer service calls             0.005236          -0.005677
# Churn                              0.033639           0.012262
#
#                         Total night charge  Total intl minutes  \
# Account length                   -0.008999            0.011369
# Area code                        -0.003382           -0.013418
# International plan               -0.010316            0.053162
# Voice mail plan                   0.001066           -0.013963
# Number vmail messages            -0.000229           -0.004156
# Total day minutes                 0.013464           -0.011042
# Total day calls                   0.008972            0.031036
# Total day charge                  0.013468           -0.011046
# Total eve minutes                -0.013450           -0.006915
# Total eve calls                  -0.000135            0.011012
# Total eve charge                 -0.013464           -0.006923
# Total night minutes               0.999999           -0.008607
# Total night calls                 0.012720           -0.023447
# Total night charge                1.000000           -0.008615
# Total intl minutes               -0.008615            1.000000
# Total intl calls                 -0.001099            0.037315
# Total intl charge                -0.008517            0.999993
# Customer service calls            0.005257           -0.002826
# Churn                             0.033635            0.086204
#
#                         Total intl calls  Total intl charge  \
# Account length                  0.017627           0.011383
# Area code                      -0.027423          -0.013534
# International plan              0.011549           0.053037
# Voice mail plan                 0.015196          -0.013931
# Number vmail messages           0.027013          -0.004136
# Total day minutes               0.005687          -0.010934
# Total day calls                 0.006928           0.031133
# Total day charge                0.005688          -0.010938
# Total eve minutes               0.002160          -0.006947
# Total eve calls                 0.003710           0.011000
# Total eve charge                0.002169          -0.006955
# Total night minutes            -0.001110          -0.008510
# Total night calls               0.019367          -0.023434
# Total night charge             -0.001099          -0.008517
# Total intl minutes              0.037315           0.999993
# Total intl calls                1.000000           0.037363
# Total intl charge               0.037363           1.000000
# Customer service calls         -0.022143          -0.002895
# Churn                          -0.069882           0.086216
#
#                         Customer service calls     Churn
# Account length                        0.002455  0.017728
# Area code                             0.034442  0.001019
# International plan                   -0.035955  0.277489
# Voice mail plan                      -0.022054 -0.099291
# Number vmail messages                -0.018787 -0.086474
# Total day minutes                    -0.024543  0.195688
# Total day calls                      -0.011945  0.018290
# Total day charge                     -0.024548  0.195689
# Total eve minutes                    -0.013192  0.072906
# Total eve calls                       0.001058 -0.001539
# Total eve charge                     -0.013196  0.072893
# Total night minutes                   0.005236  0.033639
# Total night calls                    -0.005677  0.012262
# Total night charge                    0.005257  0.033635
# Total intl minutes                   -0.002826  0.086204
# Total intl calls                     -0.022143 -0.069882
# Total intl charge                    -0.002895  0.086216
# Customer service calls                1.000000  0.202590
# Churn                                 0.202590  1.000000

# %%
plt.figure(figsize = (12,8))
sns.heatmap(df1.corr(), cmap = "rainbow")
# Out:
# C:\Users\dmaka\AppData\Local\Temp\ipykernel_12840\1449426313.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df1.corr(), cmap = "rainbow")
# <Axes: >

# %% [markdown]
# ### 5) Create features and target data. Only select features data that are highly correlated with target data.

# %%
from sklearn.feature_selection import SelectKBest , chi2

# %%
X = df1.drop(['State','Churn'],axis=1)
Y = df.iloc[:,-1]

Features = SelectKBest(score_func=chi2 , k=10)
Best_feat = Features.fit(X,Y)

dfscores = pd.DataFrame(Best_feat.scores_)
df_X = pd.DataFrame(X.columns)

best_feat = pd.concat([df_X,dfscores],axis=1)

best_feat.columns = ['Features','Scores']
BF = pd.DataFrame(best_feat.nlargest(10,'Scores'))
print(BF)
# Out:
#                   Features       Scores
# 5        Total day minutes  1670.974104
# 4    Number vmail messages   460.322168
# 7         Total day charge   284.061945
# 2       International plan   184.492057
# 8        Total eve minutes   183.515789
# 17  Customer service calls   120.347409
# 11     Total night minutes    38.655897
# 3          Voice mail plan    19.056720
# 15        Total intl calls    17.575117
# 10        Total eve charge    15.592947

# %% [markdown]
# ### 6) Scale the target data (churn)

# %%
from sklearn.preprocessing import StandardScaler

# %%
STD = StandardScaler()

# %%
df1['Churn'] = STD.fit_transform(df1[['Churn']])
df1['Churn']
# Out:
# 0      -0.412704
# 1      -0.412704
# 2      -0.412704
# 3      -0.412704
# 4      -0.412704
#           ...
# 2661   -0.412704
# 2662   -0.412704
# 2663   -0.412704
# 2664   -0.412704
# 2665   -0.412704
# Name: Churn, Length: 2666, dtype: float64

# %% [markdown]
# ### 7) Check the shape of both training data and testing data

# %%
X = df1[BF['Features']]
Y = df['Churn']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2, random_state = 42)

# %%
print("X Training size : " , X_train.shape)
print("Y Training size : " , Y_train.shape)
print("X Testing size : " , X_test.shape)
print("Y Testing size : " , Y_test.shape)
# Out:
# X Training size :  (2132, 10)
# Y Training size :  (2132,)
# X Testing size :  (534, 10)
# Y Testing size :  (534,)

# %%
BF1 = pd.DataFrame(best_feat.nlargest(5,'Scores'))
BF1['Churn'] = df['Churn'].copy()
df2 = df1[BF['Features']]
df2['Churn'] = df['Churn'].copy()
df2['Churn']
df3 = df1[BF1['Features']]
df3['Churn'] = df['Churn'].copy()
df3
# Out:
# C:\Users\dmaka\AppData\Local\Temp\ipykernel_12840\3743384247.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Churn'] = df['Churn'].copy()
# C:\Users\dmaka\AppData\Local\Temp\ipykernel_12840\3743384247.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Churn'] = df['Churn'].copy()
#       Total day minutes  Number vmail messages  Total day charge  \
# 0                 265.1                     25             45.07
# 1                 161.6                     26             27.47
# 2                 243.4                      0             41.38
# 3                 299.4                      0             50.90
# 4                 166.7                      0             28.34
# ...                 ...                    ...               ...
# 2661              134.7                      0             22.90
# 2662              156.2                     36             26.55
# 2663              231.1                      0             39.29
# 2664              180.8                      0             30.74
# 2665              234.4                     25             39.85
#
#       International plan  Total eve minutes  Churn
# 0                      0              197.4      0
# 1                      0              195.5      0
# 2                      0              121.2      0
# 3                      1               61.9      0
# 4                      1              148.3      0
# ...                  ...                ...    ...
# 2661                   0              189.7      0
# 2662                   0              215.5      0
# 2663                   0              153.4      0
# 2664                   0              288.8      0
# 2665                   0              265.9      0
#
# [2666 rows x 6 columns]

# %%
sns.pairplot(df3,hue="Churn")

# %% [markdown]
# ### 8) Apply Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
Logit = LogisticRegression()

# %%
Logit.fit(X_train,Y_train)
# Out:
# C:\Users\dmaka\anaconda3\envs\Tflow1\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print("Trainng score : ",Logit.score(X_train,Y_train))
print("Testing score : ",Logit.score(X_test,Y_test))
# Out:
# Trainng score :  0.8597560975609756
# Testing score :  0.8632958801498127

# %% [markdown]
# ### 9) Display confusion matrix

# %%
from sklearn.metrics import confusion_matrix

# %%
Y_pred = Logit.predict(X_test)

# %%
confusion = confusion_matrix(Y_test,Y_pred)
confusion
# Out:
# array([[445,  10],
#        [ 63,  16]], dtype=int64)

# %%
plt.figure(figsize=(8,5))
sns.heatmap(confusion,annot=True)
plt.xlabel('Predicted label')
plt.ylabel('Actual label')
# Out:
# Text(67.25, 0.5, 'Actual label')

# %% [markdown]
# ### 10) Perform Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
BF1 = pd.DataFrame(best_feat.nlargest(5,'Scores'))
X1 = df1[BF1['Features']]
Y1 = df['Churn'].copy()

# %%
from sklearn.model_selection import train_test_split
X1_train,X1_test,Y1_train,Y1_test = train_test_split(X1,Y1,test_size = 0.2, random_state = 42)

# %%
X1_train.shape
# Out:
# (2132, 5)

# %%
Y1_train.shape
# Out:
# (2132,)

# %%
#n_estimators = [int(x) for x in np.linspace(start=50 , stop = 1000, num = 5)]

# Grid Search CV

grid = GridSearchCV(SVC(gamma='auto'),
      {
        'C' : [1,10,20],
       'kernel' : ['rbf','linear'],
        'random_state' : [0,5,42],      
    },
    cv=5,
    n_jobs=-1,
    return_train_score=True,
)

# %% [markdown]
# ### 11) Create a model

# %%
grid.fit(X1_train,Y1_train)
score = pd.DataFrame(grid.cv_results_)

# %%
score
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.412671      0.011254         0.129426        0.006635       1
# 1        0.405975      0.012974         0.133626        0.012791       1
# 2        0.408980      0.040553         0.143124        0.023196       1
# 3       45.400130      3.622889         0.011504        0.000629       1
# 4       44.791041      3.728519         0.011504        0.000445       1
# 5       44.434883      4.051245         0.011302        0.000400       1
# 6        0.392354      0.029196         0.141524        0.020017      10
# 7        0.366744      0.015819         0.135819        0.006237      10
# 8        0.372746      0.016506         0.133215        0.005689      10
# 9       87.610590      3.033493         0.012800        0.000749      10
# 10      86.379092      3.053783         0.012806        0.000678      10
# 11      86.629791      4.090796         0.012601        0.001358      10
# 12       0.358551      0.008968         0.127324        0.001689      20
# 13       0.363744      0.005193         0.131227        0.004749      20
# 14       0.357554      0.003851         0.127716        0.001167      20
# 15      96.696025     10.472600         0.011199        0.001833      20
# 16      92.946274      6.834031         0.008400        0.002154      20
# 17      91.901674      5.822038         0.006428        0.001849      20
#
#    param_kernel param_random_state  \
# 0           rbf                  0
# 1           rbf                  5
# 2           rbf                 42
# 3        linear                  0
# 4        linear                  5
# 5        linear                 42
# 6           rbf                  0
# 7           rbf                  5
# 8           rbf                 42
# 9        linear                  0
# 10       linear                  5
# 11       linear                 42
# 12          rbf                  0
# 13          rbf                  5
# 14          rbf                 42
# 15       linear                  0
# 16       linear                  5
# 17       linear                 42
#
#                                                params  split0_test_score  \
# 0        {'C': 1, 'kernel': 'rbf', 'random_state': 0}           0.857143
# 1        {'C': 1, 'kernel': 'rbf', 'random_state': 5}           0.857143
# 2       {'C': 1, 'kernel': 'rbf', 'random_state': 42}           0.857143
# 3     {'C': 1, 'kernel': 'linear', 'random_state': 0}           0.854801
# 4     {'C': 1, 'kernel': 'linear', 'random_state': 5}           0.854801
# 5    {'C': 1, 'kernel': 'linear', 'random_state': 42}           0.854801
# 6       {'C': 10, 'kernel': 'rbf', 'random_state': 0}           0.854801
# 7       {'C': 10, 'kernel': 'rbf', 'random_state': 5}           0.854801
# 8      {'C': 10, 'kernel': 'rbf', 'random_state': 42}           0.854801
# 9    {'C': 10, 'kernel': 'linear', 'random_state': 0}           0.857143
# 10   {'C': 10, 'kernel': 'linear', 'random_state': 5}           0.857143
# 11  {'C': 10, 'kernel': 'linear', 'random_state': 42}           0.857143
# 12      {'C': 20, 'kernel': 'rbf', 'random_state': 0}           0.854801
# 13      {'C': 20, 'kernel': 'rbf', 'random_state': 5}           0.854801
# 14     {'C': 20, 'kernel': 'rbf', 'random_state': 42}           0.854801
# 15   {'C': 20, 'kernel': 'linear', 'random_state': 0}           0.866511
# 16   {'C': 20, 'kernel': 'linear', 'random_state': 5}           0.866511
# 17  {'C': 20, 'kernel': 'linear', 'random_state': 42}           0.866511
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.857143           0.859155           0.859155
# 1            0.857143           0.859155           0.859155
# 2            0.857143           0.859155           0.859155
# 3            0.854801           0.856808           0.854460
# 4            0.854801           0.856808           0.854460
# 5            0.854801           0.856808           0.854460
# 6            0.847775           0.861502           0.842723
# 7            0.847775           0.861502           0.842723
# 8            0.847775           0.861502           0.842723
# 9            0.859485           0.847418           0.856808
# 10           0.859485           0.847418           0.856808
# 11           0.859485           0.847418           0.856808
# 12           0.847775           0.861502           0.842723
# 13           0.847775           0.861502           0.842723
# 14           0.847775           0.861502           0.842723
# 15           0.871194           0.842723           0.852113
# 16           0.871194           0.842723           0.852113
# 17           0.871194           0.842723           0.852113
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score  \
# 0            0.856808         0.857881        0.001048                1
# 1            0.856808         0.857881        0.001048                1
# 2            0.856808         0.857881        0.001048                1
# 3            0.854460         0.855066        0.000884                7
# 4            0.854460         0.855066        0.000884                7
# 5            0.854460         0.855066        0.000884                7
# 6            0.849765         0.851313        0.006398               13
# 7            0.849765         0.851313        0.006398               13
# 8            0.849765         0.851313        0.006398               13
# 9            0.845070         0.853185        0.005789               10
# 10           0.845070         0.853185        0.005789               10
# 11           0.845070         0.853185        0.005789               10
# 12           0.849765         0.851313        0.006398               13
# 13           0.849765         0.851313        0.006398               13
# 14           0.849765         0.851313        0.006398               13
# 15           0.845070         0.855522        0.011411                4
# 16           0.845070         0.855522        0.011411                4
# 17           0.845070         0.855522        0.011411                4
#
#     split0_train_score  split1_train_score  split2_train_score  \
# 0             0.977126            0.971848            0.970106
# 1             0.977126            0.971848            0.970106
# 2             0.977126            0.971848            0.970106
# 3             0.855132            0.855132            0.854631
# 4             0.855132            0.855132            0.854631
# 5             0.855132            0.855132            0.854631
# 6             1.000000            0.999413            0.999414
# 7             1.000000            0.999413            0.999414
# 8             1.000000            0.999413            0.999414
# 9             0.857478            0.856891            0.856389
# 10            0.857478            0.856891            0.856389
# 11            0.857478            0.856891            0.856389
# 12            1.000000            0.999413            0.999414
# 13            1.000000            0.999413            0.999414
# 14            1.000000            0.999413            0.999414
# 15            0.857478            0.851613            0.855803
# 16            0.857478            0.851613            0.855803
# 17            0.857478            0.851613            0.855803
#
#     split3_train_score  split4_train_score  mean_train_score  std_train_score
# 0             0.977726            0.972450          0.973851         0.003025
# 1             0.977726            0.972450          0.973851         0.003025
# 2             0.977726            0.972450          0.973851         0.003025
# 3             0.855217            0.855217          0.855066         0.000221
# 4             0.855217            0.855217          0.855066         0.000221
# 5             0.855217            0.855217          0.855066         0.000221
# 6             1.000000            1.000000          0.999765         0.000287
# 7             1.000000            1.000000          0.999765         0.000287
# 8             1.000000            1.000000          0.999765         0.000287
# 9             0.855217            0.859320          0.857059         0.001353
# 10            0.855217            0.859320          0.857059         0.001353
# 11            0.855217            0.859320          0.857059         0.001353
# 12            1.000000            1.000000          0.999765         0.000287
# 13            1.000000            1.000000          0.999765         0.000287
# 14            1.000000            1.000000          0.999765         0.000287
# 15            0.859320            0.859906          0.856824         0.002978
# 16            0.859320            0.859906          0.856824         0.002978
# 17            0.859320            0.859906          0.856824         0.002978

# %% [markdown]
# ### 12) Check the model score of both training and testing data

# %%
score[['params','mean_test_score','mean_train_score']].head()
# Out:
#                                             params  mean_test_score  \
# 0     {'C': 1, 'kernel': 'rbf', 'random_state': 0}         0.857881
# 1     {'C': 1, 'kernel': 'rbf', 'random_state': 5}         0.857881
# 2    {'C': 1, 'kernel': 'rbf', 'random_state': 42}         0.857881
# 3  {'C': 1, 'kernel': 'linear', 'random_state': 0}         0.855066
# 4  {'C': 1, 'kernel': 'linear', 'random_state': 5}         0.855066
#
#    mean_train_score
# 0          0.973851
# 1          0.973851
# 2          0.973851
# 3          0.855066
# 4          0.855066

# %% [markdown]
# ### 13) Perform cross validation technique with SVM Classifier

# %%
from sklearn.model_selection import cross_val_score

# %%
kernels = ['linear','poly']
C = [1,10,20]
Avg_score = {}

for kval in kernels:
    for cval in C:
        cv_score = cross_val_score(SVC(C=cval , kernel=kval , gamma='auto'),X_train,Y_train,cv=5,n_jobs=-1)
        Avg_score['C Value : ' + str(cval)] = np.average(cv_score)

Avg_score

# %% [markdown]
# ### 14) Perform hyperparameter tuning with different classifier models

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
model_params = {
    'SVM' : {
        'Model' : SVC(gamma='auto'),
        'Params' : {
            'C' : [1,5,10],
          # 'kernel' : ['rbf','linear']
        }
    },
    
    'Random Forest' : {
        'Model' : RandomForestClassifier(),
        'Params' : {
            'n_estimators' : [10,20,30,40],
            'random_state' : [0,5,42]
        }
    },
    
     'Decision Tree' : {
        'Model' : DecisionTreeClassifier(),
        'Params' : {
            
            'criterion' : ['gini','entropy'],
            'splitter' : ['best','random'],
            'random_state' : [0,5,42]
        }
    },
    
    'Logistic Regression' : {
        'Model' : LogisticRegression(solver='liblinear',multi_class='auto'),
        'Params' : {
            'C' : [1,5,10]
        }
    }
}

# %%
scores = []

for model_name, mp in model_params.items():
    clf = GridSearchCV(mp['Model'],mp['Params'],cv=5,return_train_score=False,n_jobs=-1)
    clf.fit(X_train,Y_train)

    scores.append({
        'Model' : model_name,
        'Best Score': clf.best_score_,
        'Best Parameters': clf.best_params_
    })

# %%
HPT = pd.DataFrame(scores)
HPT

# %% [markdown]
# ### 15) Perform k-means clustering on dataset and divide it into four clusters

# %%
from sklearn.cluster import KMeans

# %%
df2 = X.copy()
df2['Churn'] = df['Churn'].copy()

# %%
KM = KMeans(n_clusters=4)
KM.fit(df2)

# %%
Predicted = KM.fit_predict(df2)
df2['Cluster'] = Predicted

# %%
cluster_1 = df2[df2.Cluster==0]
cluster_2 = df2[df2.Cluster==1]
cluster_3 = df2[df2.Cluster==2]
cluster_4 = df2[df2.Cluster==3]

# %%
plt.scatter(cluster_1.iloc[:,0],cluster_1.iloc[:,6],color='red')
plt.scatter(cluster_2.iloc[:,0],cluster_2.iloc[:,6],color='green')
plt.scatter(cluster_3.iloc[:,0],cluster_3.iloc[:,6],color='blue')
plt.scatter(cluster_4.iloc[:,0],cluster_4.iloc[:,6],color='purple')
plt.scatter(KM.cluster_centers_[:,0],KM.cluster_centers_[:,1],color='black',marker='D',label = 'Centroid')
plt.xlabel('Total day minutes')
plt.ylabel('Total night minutes')

# %%
from sklearn.metrics import silhouette_score

# %%
print(silhouette_score(df2,Predicted))

# %% [markdown]
# ### 16) Apply PCA give n components value to 3 show we only get 3 columns after applying PCA

# %%
df3 = df1.copy()
df3.drop(['State','Churn'],axis=1,inplace=True)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
Scaler = StandardScaler()
Scaler.fit(df3)
Scaled_data = Scaler.transform(df3)

# %%
Scaled_data

# %%
pca = PCA(n_components=3)
pca.fit(Scaled_data)
x_pca = pca.transform(Scaled_data)

# %%
x_pca.shape

# %% [raw]
# fig , ax = plt.subplots()
# ay = ax.twiny()
#
# ax.scatter(x_pca[:,0],x_pca[:,2],cmap='BuGn')
# ay.scatter(x_pca[:,1],x_pca[:,2],c=df['Churn'],cmap='RdPu')
